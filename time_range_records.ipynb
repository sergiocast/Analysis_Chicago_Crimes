# %%
import asyncio
import aiohttp
import pandas as pd
import nest_asyncio
nest_asyncio.apply()
from dotenv import load_dotenv
load_dotenv()
import os

# Socrata app token 
APP_TOKEN = os.getenv("CHICAGO_API_TOKEN")

# Endpoint and config
BASE_URL = "https://data.cityofchicago.org/resource/ijzp-q8t2.json"
LIMIT = 10000
CONCURRENT_REQUESTS = 5

semaphore = asyncio.Semaphore(CONCURRENT_REQUESTS)

# %%
async def fetch_batch(session, offset, retries=5):
    headers = {"X-App-Token": APP_TOKEN}
    params = {
        "$select": "date",  # Changed to fetch the 'date' column
        "$limit": LIMIT,
        "$offset": offset,
        "$where": "date IS NOT NULL"
    }
    async with semaphore:
        for attempt in range(retries):
            try:
                async with session.get(BASE_URL, headers=headers, params=params) as resp:
                    if resp.status == 200:
                        return await resp.json()
                    elif resp.status in [429, 500, 502, 503, 504]:
                        wait = 2 ** attempt
                        print(f"Retryable error {resp.status} at offset {offset}. Retrying in {wait}s...")
                        await asyncio.sleep(wait)
                    else:
                        print(f"Non-retryable error at offset {offset}: HTTP {resp.status}")
                        return []
            except Exception as e:
                print(f"Exception at offset {offset}: {e}")
        return []

async def fetch_all_data():
    all_records = []
    offset = 0

    async with aiohttp.ClientSession() as session:
        while True:
            tasks = [fetch_batch(session, offset + i * LIMIT) for i in range(CONCURRENT_REQUESTS)]
            results = await asyncio.gather(*tasks)

            batch_records = [record for batch in results if batch for record in batch]
            all_records.extend(batch_records)

            print(f"Retrieved: {len(all_records)} records...")

            if any(len(batch) < LIMIT for batch in results):
                break

            offset += CONCURRENT_REQUESTS * LIMIT

    # Convert to DataFrame and parse 'date' column
    df = pd.DataFrame(all_records)
    df["date"] = pd.to_datetime(df["date"], errors="coerce")
    return df

# ✅ Run this inside an async context (e.g., Jupyter cell)
df = await fetch_all_data()
print(f"Total records: {len(df)}")
df.head()
# Out:
# Retrieved: 50000 records...
# Retrieved: 100000 records...
# Retrieved: 150000 records...
# Retrieved: 200000 records...
# Retrieved: 250000 records...
# Retrieved: 300000 records...
# Retrieved: 350000 records...
# Retrieved: 400000 records...
# Retrieved: 450000 records...
# Retrieved: 500000 records...
# Retrieved: 550000 records...
# Retrieved: 600000 records...
# Retrieved: 650000 records...
# Retrieved: 700000 records...
# Retrieved: 750000 records...
# Retrieved: 800000 records...
# Retrieved: 850000 records...
# Retrieved: 900000 records...
# Retrieved: 950000 records...
# Retrieved: 1000000 records...
# Retrieved: 1050000 records...
# Retrieved: 1100000 records...
# Retrieved: 1150000 records...
# Retrieved: 1200000 records...
# Retrieved: 1250000 records...
# Retrieved: 1300000 records...
# Retrieved: 1350000 records...
# Retrieved: 1400000 records...
# Retrieved: 1450000 records...
# Retrieved: 1500000 records...
# Retrieved: 1550000 records...
# Retrieved: 1600000 records...
# Retrieved: 1650000 records...
# Retrieved: 1700000 records...
# Retrieved: 1750000 records...
# Retrieved: 1800000 records...
# Retrieved: 1850000 records...
# Retrieved: 1900000 records...
# Retrieved: 1950000 records...
# Retrieved: 2000000 records...
# Retrieved: 2050000 records...
# Retrieved: 2100000 records...
# Retrieved: 2150000 records...
# Retrieved: 2200000 records...
# Retrieved: 2250000 records...
# Retrieved: 2300000 records...
# Retrieved: 2350000 records...
# Retrieved: 2400000 records...
# Retrieved: 2450000 records...
# Retrieved: 2500000 records...
# Retrieved: 2550000 records...
# Retrieved: 2600000 records...
# Retrieved: 2650000 records...
# Retrieved: 2700000 records...
# Retrieved: 2750000 records...
# Retrieved: 2800000 records...
# Retrieved: 2850000 records...
# Retrieved: 2900000 records...
# Retrieved: 2950000 records...
# Retrieved: 3000000 records...
# Retrieved: 3050000 records...
# Retrieved: 3100000 records...
# Retrieved: 3150000 records...
# Retrieved: 3200000 records...
# Retrieved: 3250000 records...
# Retrieved: 3300000 records...
# Retrieved: 3350000 records...
# Retrieved: 3400000 records...
# Retrieved: 3450000 records...
# Retrieved: 3500000 records...
# Retrieved: 3550000 records...
# Retrieved: 3600000 records...
# Retrieved: 3650000 records...
# Retrieved: 3700000 records...
# Retrieved: 3750000 records...
# Retrieved: 3800000 records...
# Retrieved: 3850000 records...
# Retrieved: 3900000 records...
# Retrieved: 3950000 records...
# Retrieved: 4000000 records...
# Retrieved: 4050000 records...
# Retrieved: 4100000 records...
# Retrieved: 4150000 records...
# Retrieved: 4200000 records...
# Retrieved: 4250000 records...
# Retrieved: 4300000 records...
# Retrieved: 4350000 records...
# Retrieved: 4400000 records...
# Retrieved: 4450000 records...
# Retrieved: 4500000 records...
# Retrieved: 4550000 records...
# Retrieved: 4600000 records...
# Retrieved: 4650000 records...
# Retrieved: 4700000 records...
# Retrieved: 4750000 records...
# Retrieved: 4800000 records...
# Retrieved: 4850000 records...
# Retrieved: 4900000 records...
# Retrieved: 4950000 records...
# Retrieved: 5000000 records...
# Retrieved: 5050000 records...
# Retrieved: 5100000 records...
# Retrieved: 5150000 records...
# Retrieved: 5200000 records...
# Retrieved: 5250000 records...
# Retrieved: 5300000 records...
# Retrieved: 5350000 records...
# Retrieved: 5400000 records...
# Retrieved: 5450000 records...
# Retrieved: 5500000 records...
# Retrieved: 5550000 records...
# Retrieved: 5600000 records...
# Retrieved: 5650000 records...
# Retrieved: 5700000 records...
# Retrieved: 5750000 records...
# Retrieved: 5800000 records...
# Retrieved: 5850000 records...
# Retrieved: 5900000 records...
# Retrieved: 5950000 records...
# Retrieved: 6000000 records...
# Retrieved: 6050000 records...
# Retrieved: 6100000 records...
# Retrieved: 6150000 records...
# Retrieved: 6200000 records...
# Retrieved: 6250000 records...
# Retrieved: 6300000 records...
# Retrieved: 6350000 records...
# Retrieved: 6400000 records...
# Retrieved: 6450000 records...
# Retrieved: 6500000 records...
# Retrieved: 6550000 records...
# Retrieved: 6600000 records...
# Retrieved: 6650000 records...
# Retrieved: 6700000 records...
# Retrieved: 6750000 records...
# Retrieved: 6800000 records...
# Retrieved: 6850000 records...
# Retrieved: 6900000 records...
# Retrieved: 6950000 records...
# Retrieved: 7000000 records...
# Retrieved: 7050000 records...
# Retrieved: 7100000 records...
# Retrieved: 7150000 records...
# Retrieved: 7200000 records...
# Retrieved: 7250000 records...
# Retrieved: 7300000 records...
# Retrieved: 7350000 records...
# Retrieved: 7400000 records...
# Retrieved: 7450000 records...
# Retrieved: 7500000 records...
# Retrieved: 7550000 records...
# Retrieved: 7600000 records...
# Retrieved: 7650000 records...
# Retrieved: 7700000 records...
# Retrieved: 7750000 records...
# Retrieved: 7800000 records...
# Retrieved: 7850000 records...
# Retrieved: 7900000 records...
# Retrieved: 7950000 records...
# Retrieved: 8000000 records...
# Retrieved: 8050000 records...
# Retrieved: 8100000 records...
# Retrieved: 8150000 records...
# Retrieved: 8200000 records...
# Retrieved: 8250000 records...
# Retrieved: 8300000 records...
# Retrieved: 8350000 records...
# Retrieved: 8360989 records...
# Total records: 8360989
#                  date
# 0 2022-07-29 03:39:00
# 1 2023-01-03 16:44:00
# 2 2020-08-10 09:45:00
# 3 2017-08-26 10:00:00
# 4 2023-09-06 17:00:00

# %%
# Ensure date is in datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Drop rows with missing dates
df = df.dropna(subset=['date'])

# Extract hour and year
df['hour'] = df['date'].dt.hour
df['year'] = df['date'].dt.year

# ✅ Filter to years 2010–2019
df = df[(df['year'] >= 2010) & (df['year'] <= 2019)]

# Define time ranges using hour
def get_time_range(hour):
    if 4 <= hour < 7:
        return "4am–7am"
    elif 7 <= hour < 12:
        return "7am–12pm"
    elif 12 <= hour < 17:
        return "12pm–5pm"
    elif 18 <= hour < 21:
        return "6pm–9pm"
    elif 21 <= hour <= 23:
        return "9pm–12am"
    else:
        return "12am–4am"

# Apply time range function
df['time_range'] = df['hour'].apply(get_time_range)

# Group by time range and year
time_year_counts = df.groupby(['time_range', 'year']).size().reset_index(name='count')

# Optional: Sort for readability
time_range_order = ["12am–4am", "4am–7am", "7am–12pm", "12pm–5pm", "6pm–9pm", "9pm–12am"]
time_year_counts['time_range'] = pd.Categorical(time_year_counts['time_range'], categories=time_range_order, ordered=True)
time_year_counts = time_year_counts.sort_values(['year', 'time_range'])

# Show result
print(time_year_counts.head())

# ✅ Export to CSV
time_year_counts.to_csv("time_range_counts_2010_2019.csv", index=False)
print("Exported to 'time_range_counts_2010_2019.csv'")
